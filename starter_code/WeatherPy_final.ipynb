# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | isafjordur
# Processing Record 3 of Set 1 | zaruma
# Processing Record 4 of Set 1 | florence
# Processing Record 5 of Set 1 | dawei
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | berdigestyakh
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | qaqortoq
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | barra de santo antonio
# Processing Record 15 of Set 1 | tubarjal
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | yarkovo
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | metlili chaamba
# Processing Record 21 of Set 1 | alice springs
# Processing Record 22 of Set 1 | basco
# Processing Record 23 of Set 1 | griffith
# Processing Record 24 of Set 1 | spirit lake
# Processing Record 25 of Set 1 | margaret river
# Processing Record 26 of Set 1 | jianshui
# Processing Record 27 of Set 1 | alamos
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | bilibino
# Processing Record 30 of Set 1 | nemuro
# Processing Record 31 of Set 1 | hamilton
# Processing Record 32 of Set 1 | chibougamau
# Processing Record 33 of Set 1 | hawaiian paradise park
# Processing Record 34 of Set 1 | port-aux-francais
# Processing Record 35 of Set 1 | anadyr
# Processing Record 36 of Set 1 | kawthoung
# City not found. Skipping...
# Processing Record 37 of Set 1 | ishigaki
# Processing Record 38 of Set 1 | montes claros
# Processing Record 39 of Set 1 | jeremie
# Processing Record 40 of Set 1 | port mathurin
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | magadan
# Processing Record 44 of Set 1 | aasiaat
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | washington
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | kapuskasing
# Processing Record 49 of Set 1 | shimoda
# Processing Record 50 of Set 1 | murzuq
# Processing Record 0 of Set 2 | okhotsk
# Processing Record 1 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 2 | katsuren-haebaru
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | waingapu
# Processing Record 5 of Set 2 | bucerias
# Processing Record 6 of Set 2 | queenstown
# Processing Record 7 of Set 2 | tazovsky
# Processing Record 8 of Set 2 | whitehorse
# Processing Record 9 of Set 2 | lazaro cardenas
# Processing Record 10 of Set 2 | constantia
# Processing Record 11 of Set 2 | invercargill
# Processing Record 12 of Set 2 | moyale
# Processing Record 13 of Set 2 | atafu village
# Processing Record 14 of Set 2 | maun
# Processing Record 15 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 2 | tezpur
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | tanout
# Processing Record 19 of Set 2 | sheridan
# Processing Record 20 of Set 2 | mahdishahr
# Processing Record 21 of Set 2 | coquimbo
# Processing Record 22 of Set 2 | daru
# Processing Record 23 of Set 2 | vitebsk
# Processing Record 24 of Set 2 | fort st. john
# Processing Record 25 of Set 2 | saipan
# Processing Record 26 of Set 2 | el calafate
# Processing Record 27 of Set 2 | remire-montjoly
# Processing Record 28 of Set 2 | waddan
# Processing Record 29 of Set 2 | mirny
# Processing Record 30 of Set 2 | sinabang
# Processing Record 31 of Set 2 | vorgashor
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | checker hall
# City not found. Skipping...
# Processing Record 34 of Set 2 | puerto baquerizo moreno
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | babolsar
# Processing Record 37 of Set 2 | george town
# Processing Record 38 of Set 2 | trzemeszno
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | labytnangi
# Processing Record 41 of Set 2 | trairi
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | tromso
# Processing Record 44 of Set 2 | muskogee
# Processing Record 45 of Set 2 | mao
# Processing Record 46 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 47 of Set 2 | mahanoro
# Processing Record 48 of Set 2 | cartagena del chaira
# Processing Record 49 of Set 2 | dimako
# Processing Record 0 of Set 3 | codrington
# Processing Record 1 of Set 3 | beykonak
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | urangan
# Processing Record 4 of Set 3 | mount isa
# Processing Record 5 of Set 3 | akureyri
# Processing Record 6 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 3 | burang
# Processing Record 8 of Set 3 | prince rupert
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | wailua homesteads
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | porto barra do ivinheima
# Processing Record 13 of Set 3 | san rafael
# Processing Record 14 of Set 3 | mukalla
# Processing Record 15 of Set 3 | kzyltu
# Processing Record 16 of Set 3 | terrace
# Processing Record 17 of Set 3 | nacozari viejo
# Processing Record 18 of Set 3 | i-n-salah
# Processing Record 19 of Set 3 | shibli-umm al-ghanam
# City not found. Skipping...
# Processing Record 20 of Set 3 | wanning
# Processing Record 21 of Set 3 | samarra'
# City not found. Skipping...
# Processing Record 22 of Set 3 | san martin
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | conduaga
# Processing Record 26 of Set 3 | monastyryshche
# Processing Record 27 of Set 3 | maceio
# Processing Record 28 of Set 3 | borgo san lorenzo
# Processing Record 29 of Set 3 | ojinaga
# Processing Record 30 of Set 3 | coronel dorrego
# Processing Record 31 of Set 3 | ashland
# Processing Record 32 of Set 3 | weno
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | quellon
# Processing Record 35 of Set 3 | hadibu
# Processing Record 36 of Set 3 | horta
# Processing Record 37 of Set 3 | mount pleasant
# Processing Record 38 of Set 3 | san isidro
# Processing Record 39 of Set 3 | port saint john's
# Processing Record 40 of Set 3 | udachny
# Processing Record 41 of Set 3 | saint-pierre
# Processing Record 42 of Set 3 | matthew town
# Processing Record 43 of Set 3 | chonchi
# Processing Record 44 of Set 3 | sao vicente
# Processing Record 45 of Set 3 | dudinka
# Processing Record 46 of Set 3 | kitimat
# Processing Record 47 of Set 3 | kingston
# Processing Record 48 of Set 3 | ixtapa
# Processing Record 49 of Set 3 | pathein
# Processing Record 0 of Set 4 | stanley
# Processing Record 1 of Set 4 | pyinmana
# Processing Record 2 of Set 4 | al jawf
# Processing Record 3 of Set 4 | glodeni
# Processing Record 4 of Set 4 | arak
# Processing Record 5 of Set 4 | olonkinbyen
# Processing Record 6 of Set 4 | pangody
# Processing Record 7 of Set 4 | happy valley-goose bay
# Processing Record 8 of Set 4 | iskateley
# Processing Record 9 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | lihue
# Processing Record 12 of Set 4 | igrim
# Processing Record 13 of Set 4 | santyoku
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | igarka
# Processing Record 19 of Set 4 | tolanaro
# Processing Record 20 of Set 4 | papatowai
# Processing Record 21 of Set 4 | gargalianoi
# Processing Record 22 of Set 4 | sur
# Processing Record 23 of Set 4 | machachi
# Processing Record 24 of Set 4 | general pinedo
# Processing Record 25 of Set 4 | utrik
# Processing Record 26 of Set 4 | bahar
# Processing Record 27 of Set 4 | wynyard
# Processing Record 28 of Set 4 | mili
# Processing Record 29 of Set 4 | shumen
# Processing Record 30 of Set 4 | san antonio de pale
# Processing Record 31 of Set 4 | mammoth lakes
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | soe
# Processing Record 34 of Set 4 | rongelap
# Processing Record 35 of Set 4 | pingliang
# Processing Record 36 of Set 4 | aripuana
# Processing Record 37 of Set 4 | afaahiti
# Processing Record 38 of Set 4 | pihuamo
# Processing Record 39 of Set 4 | inhambane
# Processing Record 40 of Set 4 | tsiroanomandidy
# Processing Record 41 of Set 4 | villamontes
# Processing Record 42 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | uray
# Processing Record 45 of Set 4 | cockburn town
# Processing Record 46 of Set 4 | enewetak
# Processing Record 47 of Set 4 | tell city
# Processing Record 48 of Set 4 | udomlya
# Processing Record 49 of Set 4 | arno
# Processing Record 0 of Set 5 | longyearbyen
# Processing Record 1 of Set 5 | al 'amarah
# Processing Record 2 of Set 5 | cullinan
# Processing Record 3 of Set 5 | kapenguria
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | nabire
# Processing Record 6 of Set 5 | tabuk
# Processing Record 7 of Set 5 | kenai
# Processing Record 8 of Set 5 | holualoa
# Processing Record 9 of Set 5 | ranot
# Processing Record 10 of Set 5 | nevel'sk
# Processing Record 11 of Set 5 | korets
# Processing Record 12 of Set 5 | punta arenas
# Processing Record 13 of Set 5 | trashi yangtse
# Processing Record 14 of Set 5 | fuyang
# Processing Record 15 of Set 5 | santa rita
# Processing Record 16 of Set 5 | praia da vitoria
# Processing Record 17 of Set 5 | caleta de carquin
# Processing Record 18 of Set 5 | cooper's town
# Processing Record 19 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | labrador city
# Processing Record 22 of Set 5 | tingi
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | san miguel
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | mendefera
# Processing Record 29 of Set 5 | brookings
# Processing Record 30 of Set 5 | kudahuvadhoo
# Processing Record 31 of Set 5 | arhavi
# Processing Record 32 of Set 5 | ola
# Processing Record 33 of Set 5 | kroonstad
# Processing Record 34 of Set 5 | nantucket
# Processing Record 35 of Set 5 | olyokminsk
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | ulan bator
# Processing Record 39 of Set 5 | kavaratti
# Processing Record 40 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 41 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 42 of Set 5 | hammerfest
# Processing Record 43 of Set 5 | brokopondo
# Processing Record 44 of Set 5 | gadzhiyevo
# Processing Record 45 of Set 5 | kolkhozobod
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 48 of Set 5 | alaghsas
# Processing Record 49 of Set 5 | bonthe
# Processing Record 0 of Set 6 | leo
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | la passe
# Processing Record 3 of Set 6 | galliano
# Processing Record 4 of Set 6 | meadow lake
# Processing Record 5 of Set 6 | victorica
# Processing Record 6 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 7 of Set 6 | ulladulla
# Processing Record 8 of Set 6 | eirunepe
# Processing Record 9 of Set 6 | paicandu
# Processing Record 10 of Set 6 | castillos
# Processing Record 11 of Set 6 | papao
# Processing Record 12 of Set 6 | envira
# Processing Record 13 of Set 6 | warwick
# Processing Record 14 of Set 6 | gaiman
# Processing Record 15 of Set 6 | borogontsy
# Processing Record 16 of Set 6 | guiuan
# Processing Record 17 of Set 6 | sovetskaya gavan'
# Processing Record 18 of Set 6 | alofi
# Processing Record 19 of Set 6 | jiuquan
# Processing Record 20 of Set 6 | glace bay
# Processing Record 21 of Set 6 | pandan
# Processing Record 22 of Set 6 | lusambo
# Processing Record 23 of Set 6 | moranbah
# Processing Record 24 of Set 6 | yelizovo
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | tsiombe
# Processing Record 27 of Set 6 | sao jose da coroa grande
# Processing Record 28 of Set 6 | jamestown
# Processing Record 29 of Set 6 | sisimiut
# Processing Record 30 of Set 6 | ha'il
# Processing Record 31 of Set 6 | bundaberg north
# Processing Record 32 of Set 6 | tralee
# Processing Record 33 of Set 6 | sumenep
# Processing Record 34 of Set 6 | ta`u
# Processing Record 35 of Set 6 | acarau
# Processing Record 36 of Set 6 | corn island
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | felipe carrillo puerto
# Processing Record 39 of Set 6 | hoa binh
# Processing Record 40 of Set 6 | chuhar jamali
# Processing Record 41 of Set 6 | nova sintra
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | oistins
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | lindsay
# Processing Record 46 of Set 6 | wetaskiwin
# Processing Record 47 of Set 6 | kudat
# Processing Record 48 of Set 6 | erenhot
# Processing Record 49 of Set 6 | chu
# Processing Record 0 of Set 7 | prado
# Processing Record 1 of Set 7 | omuthiya
# City not found. Skipping...
# Processing Record 2 of Set 7 | aioun
# Processing Record 3 of Set 7 | pariaman
# Processing Record 4 of Set 7 | siedlce
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | chinde
# Processing Record 7 of Set 7 | hithadhoo
# Processing Record 8 of Set 7 | agat village
# Processing Record 9 of Set 7 | manistee
# Processing Record 10 of Set 7 | selkirk
# Processing Record 11 of Set 7 | kourou
# Processing Record 12 of Set 7 | lamia
# Processing Record 13 of Set 7 | iranshahr
# Processing Record 14 of Set 7 | upata
# Processing Record 15 of Set 7 | la gi
# Processing Record 16 of Set 7 | tangalle
# Processing Record 17 of Set 7 | tazacorte
# Processing Record 18 of Set 7 | walvis bay
# Processing Record 19 of Set 7 | san luis de la loma
# Processing Record 20 of Set 7 | akrehamn
# Processing Record 21 of Set 7 | achinsk
# Processing Record 22 of Set 7 | okha
# Processing Record 23 of Set 7 | mar del plata
# Processing Record 24 of Set 7 | qarqaraly
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | olinda
# Processing Record 27 of Set 7 | lodwar
# Processing Record 28 of Set 7 | mbanza kongo
# Processing Record 29 of Set 7 | shenjiamen
# Processing Record 30 of Set 7 | cozumel
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | lospalos
# Processing Record 33 of Set 7 | rustaq
# Processing Record 34 of Set 7 | carnarvon
# Processing Record 35 of Set 7 | luderitz
# Processing Record 36 of Set 7 | winnemucca
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | funafuti
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | berezovyy
# Processing Record 41 of Set 7 | ketchikan
# Processing Record 42 of Set 7 | inarajan village
# Processing Record 43 of Set 7 | an ros
# Processing Record 44 of Set 7 | salinas
# Processing Record 45 of Set 7 | vadso
# Processing Record 46 of Set 7 | khandyga
# Processing Record 47 of Set 7 | ust-nera
# Processing Record 48 of Set 7 | novyy urgal
# Processing Record 49 of Set 7 | kilindoni
# Processing Record 0 of Set 8 | ciudad bolivar
# Processing Record 1 of Set 8 | arraial do cabo
# Processing Record 2 of Set 8 | toulepleu guere
# Processing Record 3 of Set 8 | avarua
# Processing Record 4 of Set 8 | verkhnevilyuysk
# Processing Record 5 of Set 8 | broome
# Processing Record 6 of Set 8 | ruidoso
# Processing Record 7 of Set 8 | tocopilla
# Processing Record 8 of Set 8 | petoskey
# Processing Record 9 of Set 8 | taltal
# Processing Record 10 of Set 8 | juneau
# Processing Record 11 of Set 8 | charters towers
# Processing Record 12 of Set 8 | wamba
# Processing Record 13 of Set 8 | bowen
# Processing Record 14 of Set 8 | bulawayo
# Processing Record 15 of Set 8 | campo maior
# Processing Record 16 of Set 8 | kharp
# Processing Record 17 of Set 8 | salekhard
# Processing Record 18 of Set 8 | mount pearl
# Processing Record 19 of Set 8 | san juan bautista
# Processing Record 20 of Set 8 | georgetown
# Processing Record 21 of Set 8 | neryungri
# Processing Record 22 of Set 8 | mahibadhoo
# Processing Record 23 of Set 8 | magong
# Processing Record 24 of Set 8 | behompy
# Processing Record 25 of Set 8 | maragogi
# Processing Record 26 of Set 8 | el granada
# Processing Record 27 of Set 8 | bargara
# City not found. Skipping...
# Processing Record 28 of Set 8 | las tablas
# Processing Record 29 of Set 8 | stanthorpe
# Processing Record 30 of Set 8 | badger
# Processing Record 31 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 8 | badiyah
# Processing Record 33 of Set 8 | gornopravdinsk
# Processing Record 34 of Set 8 | minas de marcona
# Processing Record 35 of Set 8 | altar
# Processing Record 36 of Set 8 | bang len
# Processing Record 37 of Set 8 | fort bragg
# Processing Record 38 of Set 8 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 39 of Set 8 | phetchabun
# Processing Record 40 of Set 8 | hassi messaoud
# Processing Record 41 of Set 8 | mucumpiz
# Processing Record 42 of Set 8 | nizhneangarsk
# Processing Record 43 of Set 8 | santa marta
# Processing Record 44 of Set 8 | lijiang
# Processing Record 45 of Set 8 | gongdanglegi kulon
# Processing Record 46 of Set 8 | hasaki
# Processing Record 47 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 8 | melfort
# Processing Record 49 of Set 8 | fada
# Processing Record 0 of Set 9 | ingeniero guillermo n. juarez
# Processing Record 1 of Set 9 | curup
# Processing Record 2 of Set 9 | biloela
# Processing Record 3 of Set 9 | howard springs
# Processing Record 4 of Set 9 | fale old settlement
# Processing Record 5 of Set 9 | san andres
# Processing Record 6 of Set 9 | bel ombre
# Processing Record 7 of Set 9 | eyl
# Processing Record 8 of Set 9 | nova xavantina
# Processing Record 9 of Set 9 | boguchany
# Processing Record 10 of Set 9 | sanctuary point
# Processing Record 11 of Set 9 | severo-yeniseyskiy
# Processing Record 12 of Set 9 | fairbanks
# Processing Record 13 of Set 9 | coxim
# Processing Record 14 of Set 9 | lae
# Processing Record 15 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 17 of Set 9 | argo
# Processing Record 18 of Set 9 | pangoa
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | newman
# Processing Record 21 of Set 9 | bugul'ma
# Processing Record 22 of Set 9 | tanrake village
# City not found. Skipping...
# Processing Record 23 of Set 9 | colonia
# Processing Record 24 of Set 9 | kapa'a
# Processing Record 25 of Set 9 | howrah
# Processing Record 26 of Set 9 | laojunmiao
# Processing Record 27 of Set 9 | shingu
# Processing Record 28 of Set 9 | christchurch
# Processing Record 29 of Set 9 | kaiyuan
# Processing Record 30 of Set 9 | forest grove
# Processing Record 31 of Set 9 | am djarass
# City not found. Skipping...
# Processing Record 32 of Set 9 | palmer
# Processing Record 33 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 9 | vorkuta
# Processing Record 35 of Set 9 | gorontalo
# Processing Record 36 of Set 9 | bolondron
# Processing Record 37 of Set 9 | itoman
# Processing Record 38 of Set 9 | murmashi
# Processing Record 39 of Set 9 | coahuayana de hidalgo
# Processing Record 40 of Set 9 | iacu
# Processing Record 41 of Set 9 | luanda
# Processing Record 42 of Set 9 | vilyuchinsk
# Processing Record 43 of Set 9 | gualaceo
# Processing Record 44 of Set 9 | marolambo
# Processing Record 45 of Set 9 | carutapera
# Processing Record 46 of Set 9 | leava
# Processing Record 47 of Set 9 | brenham
# Processing Record 48 of Set 9 | mount gambier
# Processing Record 49 of Set 9 | nar'yan-mar
# Processing Record 0 of Set 10 | klyuchi
# Processing Record 1 of Set 10 | huetor vega
# Processing Record 2 of Set 10 | la maddalena
# Processing Record 3 of Set 10 | es castell
# Processing Record 4 of Set 10 | monte urano
# Processing Record 5 of Set 10 | al ghayzah
# Processing Record 6 of Set 10 | eloy
# Processing Record 7 of Set 10 | susuman
# Processing Record 8 of Set 10 | aykhal
# Processing Record 9 of Set 10 | corinto
# Processing Record 10 of Set 10 | arvayheer
# Processing Record 11 of Set 10 | gulf shores
# Processing Record 12 of Set 10 | kolonia
# Processing Record 13 of Set 10 | freetown
# Processing Record 14 of Set 10 | kakanj
# Processing Record 15 of Set 10 | taroa
# Processing Record 16 of Set 10 | kamen'-rybolov
# Processing Record 17 of Set 10 | live oak
# Processing Record 18 of Set 10 | tinana
# City not found. Skipping...
# Processing Record 19 of Set 10 | razdol'noye
# Processing Record 20 of Set 10 | bukama
# Processing Record 21 of Set 10 | nuuk
# Processing Record 22 of Set 10 | kuqa
# Processing Record 23 of Set 10 | loma de cabrera
# Processing Record 24 of Set 10 | lebowakgomo
# Processing Record 25 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 10 | ouesso
# Processing Record 28 of Set 10 | narvik
# Processing Record 29 of Set 10 | cidade velha
# Processing Record 30 of Set 10 | auce
# Processing Record 31 of Set 10 | kulhudhuffushi
# Processing Record 32 of Set 10 | manicore
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | selfoss
# Processing Record 35 of Set 10 | kovur
# Processing Record 36 of Set 10 | albina
# Processing Record 37 of Set 10 | tabalah
# Processing Record 38 of Set 10 | new plymouth
# Processing Record 39 of Set 10 | prainha
# Processing Record 40 of Set 10 | juan griego
# Processing Record 41 of Set 10 | princeville
# Processing Record 42 of Set 10 | noyabrsk
# Processing Record 43 of Set 10 | gaoual
# Processing Record 44 of Set 10 | peniche
# Processing Record 45 of Set 10 | borinskoye
# Processing Record 46 of Set 10 | hargeysa
# Processing Record 47 of Set 10 | vernon
# Processing Record 48 of Set 10 | west bay
# Processing Record 49 of Set 10 | ebon
# Processing Record 0 of Set 11 | dunedin
# Processing Record 1 of Set 11 | mugia
# Processing Record 2 of Set 11 | oliver
# Processing Record 3 of Set 11 | sassandra
# Processing Record 4 of Set 11 | shitanjing
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | prince george
# Processing Record 7 of Set 11 | aksu
# Processing Record 8 of Set 11 | uturoa
# Processing Record 9 of Set 11 | kodok
# City not found. Skipping...
# Processing Record 10 of Set 11 | khenifra
# Processing Record 11 of Set 11 | buala
# Processing Record 12 of Set 11 | kununurra
# Processing Record 13 of Set 11 | vila velha
# Processing Record 14 of Set 11 | pedreira
# Processing Record 15 of Set 11 | choma
# Processing Record 16 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 17 of Set 11 | gilgit
# Processing Record 18 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 19 of Set 11 | istgah-e rah ahan-e garmsar
# Processing Record 20 of Set 11 | shohimardon
# Processing Record 21 of Set 11 | road town
# Processing Record 22 of Set 11 | okola
# Processing Record 23 of Set 11 | teruel
# Processing Record 24 of Set 11 | lasem
# Processing Record 25 of Set 11 | as saff
# Processing Record 26 of Set 11 | portland
# Processing Record 27 of Set 11 | dodge city
# Processing Record 28 of Set 11 | malango
# Processing Record 29 of Set 11 | port douglas
# Processing Record 30 of Set 11 | ebaye
# Processing Record 31 of Set 11 | kidal
# Processing Record 32 of Set 11 | umba
# Processing Record 33 of Set 11 | minot air force base
# Processing Record 34 of Set 11 | ilhabela
# Processing Record 35 of Set 11 | moroni
# Processing Record 36 of Set 11 | andergrove
# Processing Record 37 of Set 11 | carolina beach
# Processing Record 38 of Set 11 | gebeit
# Processing Record 39 of Set 11 | sarandi del yi
# Processing Record 40 of Set 11 | metkovic
# Processing Record 41 of Set 11 | makokou
# Processing Record 42 of Set 11 | svobodnyy
# Processing Record 43 of Set 11 | maymana
# Processing Record 44 of Set 11 | mpulungu
# Processing Record 45 of Set 11 | bria
# Processing Record 46 of Set 11 | saint-dizier
# Processing Record 47 of Set 11 | crane
# Processing Record 48 of Set 11 | bani walid
# Processing Record 49 of Set 11 | tercan
# Processing Record 0 of Set 12 | toktogul
# Processing Record 1 of Set 12 | mil'kovo
# Processing Record 2 of Set 12 | vila franca do campo
# Processing Record 3 of Set 12 | toliara
# Processing Record 4 of Set 12 | rakops
# Processing Record 5 of Set 12 | yaring
# Processing Record 6 of Set 12 | yangambi
# Processing Record 7 of Set 12 | burnie
# Processing Record 8 of Set 12 | usogorsk
# Processing Record 9 of Set 12 | sinan
# Processing Record 10 of Set 12 | muisne
# Processing Record 11 of Set 12 | liman
# Processing Record 12 of Set 12 | nicoya
# Processing Record 13 of Set 12 | morrilton
# Processing Record 14 of Set 12 | bac lieu
# Processing Record 15 of Set 12 | alexandria
# Processing Record 16 of Set 12 | bodo
# Processing Record 17 of Set 12 | puerto santander
# Processing Record 18 of Set 12 | haymana
# Processing Record 19 of Set 12 | thanh hoa
# Processing Record 20 of Set 12 | potosi
# Processing Record 21 of Set 12 | raduzhnyy
# Processing Record 22 of Set 12 | hampton bays
# Processing Record 23 of Set 12 | maintirano
# Processing Record 24 of Set 12 | sinop
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | bam
# Processing Record 27 of Set 12 | aitape
# Processing Record 28 of Set 12 | grand falls-windsor
# Processing Record 29 of Set 12 | utuado
# Processing Record 30 of Set 12 | edson
# Processing Record 31 of Set 12 | st. john's
# Processing Record 32 of Set 12 | port augusta
# Processing Record 33 of Set 12 | kargil
# Processing Record 34 of Set 12 | aqadyr
# Processing Record 35 of Set 12 | lorengau
# Processing Record 36 of Set 12 | keflavik
# Processing Record 37 of Set 12 | inari
# Processing Record 38 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 39 of Set 12 | thai nguyen
# Processing Record 40 of Set 12 | ponta delgada
# Processing Record 41 of Set 12 | vanimo
# Processing Record 42 of Set 12 | sirte
# Processing Record 43 of Set 12 | yarmouth
# Processing Record 44 of Set 12 | port-vila
# Processing Record 45 of Set 12 | seguin
# Processing Record 46 of Set 12 | luganville
# Processing Record 47 of Set 12 | yamada
# Processing Record 48 of Set 12 | cuttack
# Processing Record 49 of Set 12 | nadi
# Processing Record 0 of Set 13 | dongola
# Processing Record 1 of Set 13 | nadym
# Processing Record 2 of Set 13 | motupe
# Processing Record 3 of Set 13 | primorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   adamstown -25.0660 -130.1015    293.39        71          69       10.11
# 1  isafjordur  66.0755  -23.1240    285.17        58           0        0.00
# 2      zaruma  -3.6833  -79.6167    290.23        83          49        1.71
# 3    florence  43.7667   11.2500    311.68        33           0        2.57
# 4       dawei  14.0833   98.2000    298.91        90          44        1.32
#
#   Country        Date
# 0      PN  1692014181
# 1      IS  1692014181
# 2      EC  1692014181
# 3      IT  1692014176
# 4      MM  1692014181

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         adamstown -25.0660 -130.1015    293.39        71          69
# 1        isafjordur  66.0755  -23.1240    285.17        58           0
# 2            zaruma  -3.6833  -79.6167    290.23        83          49
# 3          florence  43.7667   11.2500    311.68        33           0
# 4             dawei  14.0833   98.2000    298.91        90          44
#
#          Wind Speed Country        Date
# City_ID
# 0             10.11      PN  1692014181
# 1              0.00      IS  1692014181
# 2              1.71      EC  1692014181
# 3              2.57      IT  1692014176
# 4              1.32      MM  1692014181

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime. now()
date = date.strftime("%m-%d-%Y")


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 8
#       1 # Build the scatter plots for latitude vs. cloudiness
#       2 # YOUR CODE HERE
#       3
#    (...)
#       6
#       7 # Save the figure
# ----> 8 plt.savefig("output_data/Fig3.png")
#      10 # Show plot
#      11 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/Fig3.png'

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')

# %% [markdown]
# **Discussion about the linear relationship:** the closer the latitude and longitude get to zero, the higher the temperature. this expresses itself as a negative correlation in the northern hemisphere and as positive in the southern hemisphere.As the lattitude gets farther away from zero, the max temp decreases. there is a strong correlation between these values

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')

# %% [markdown]
# **Discussion about the linear relationship:** with a very low r value, there is not a strong linear correlation between humidity and latidute. we cannot predict what the humidity will be based on an area's latitide. this is true for both the northern and southern hemispheres

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')

# %% [markdown]
# **Discussion about the linear relationship:** there is a slight negative correlation between cloudiness and latitude in both the northern and southern hemispheres. this is interesting because you would expect data from the northern and southern hemispheres to be inverse of each other. as the latitiude increases, in both hemispheres, there is a slight chance that the weather will be less cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')

# %% [markdown]
# **Discussion about the linear relationship:** there is very little correlation between wind speed and latitude in both the northern and southern hemisphere, with r values of -.12 and -.06 respectively. it is difficult to predict wind speed based on latitude, though there is a stronger correlation in the northern hemisphere.
